# %%
import pandas as pd
import numpy as np
from loaders import *
import pandas as pd
import seaborn as sns

# %%
des1 = [run_timeloop_mapper(
    ConfigRegistry.DES1_ARCH,
    ConfigRegistry.DES1_COMPONENTS,
    prob,
    ConfigRegistry.DES1_CONSTRAINTS,
    ConfigRegistry.DES1_MAPPER
) for prob in [
    ConfigRegistry.PROB_LAYER1,
    ConfigRegistry.PROB_LAYER2,
    ConfigRegistry.PROB_LAYER3,
    ConfigRegistry.PROB_LAYER4]]
# Out:
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# ...
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension I = 16
#   Factorization options along problem dimension O = 70
#   Factorization options along problem dimension N = 9
# Mapspace Dimension [IndexFactorization] Size: 10080
# ...

# %%
print(des1[1][1])
# Out:
# DRAM [ Inputs:1156 (1156) Weights:544 (544) Outputs:544 (544) ]
# ---------------------------------------------------------------
# | for O in [0:2)
# |   for N in [0:17)
#
# global_buffer [ Inputs:68 (68) Weights:16 (16) Outputs:272 (272) ]
# ------------------------------------------------------------------
# |     for N in [0:1)
# |       for I in [0:34) (Spatial-X)
#
# scratchpad [ Outputs:8 (8) ]
# ----------------------------
# |         for N in [0:2)
# |           for O in [0:8)
#
# weights_reg [ Weights:1 (1) ]
# -----------------------------
# |             for N in [0:1)
#
# input_activation_reg [ Inputs:1 (1) ]
# -------------------------------------
# |               for N in [0:1)
#
# output_activation_reg [ Outputs:1 (1) ]
# ---------------------------------------
# |                 for N in [0:1)

# %%
print(des1[0][0])
# Out:
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 34 (34*1)
#     Compute energy        : 3.27 pJ
#
#     STATS
#     -----
#     Utilized instances      : 34
#     Computes (total)        : 18496
#     Cycles                  : 544
#     Energy (total)          : 60574.40 pJ
#     Area (total)            : 58701.00 um^2
#
# Level 1
# -------
# === output_activation_reg ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 34 (34*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
# ...

# %%
print(des1[1][0])
# Out:
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 34 (34*1)
#     Compute energy        : 3.27 pJ
#
#     STATS
#     -----
#     Utilized instances      : 34
#     Computes (total)        : 18496
#     Cycles                  : 544
#     Energy (total)          : 60574.40 pJ
#     Area (total)            : 58701.00 um^2
#
# Level 1
# -------
# === output_activation_reg ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 34 (34*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
# ...

# %%
print(des1[2][0])
# Out:
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 34 (34*1)
#     Compute energy        : 3.27 pJ
#
#     STATS
#     -----
#     Utilized instances      : 16
#     Computes (total)        : 2176
#     Cycles                  : 136
#     Energy (total)          : 7126.40 pJ
#     Area (total)            : 58701.00 um^2
#
# Level 1
# -------
# === output_activation_reg ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 34 (34*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
# ...

# %%
print(des1[3][0])
# Out:
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 34 (34*1)
#     Compute energy        : 3.27 pJ
#
#     STATS
#     -----
#     Utilized instances      : 34
#     Computes (total)        : 4624
#     Cycles                  : 136
#     Energy (total)          : 15143.60 pJ
#     Area (total)            : 58701.00 um^2
#
# Level 1
# -------
# === output_activation_reg ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 34 (34*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
# ...

# %%
# 2 x 17
latencies = [18496, 18496, 2176, 4624]
pj_computes = [29.32, 32.95, 54.15, 50.05]
latency = sum(latencies)
pj_compute = sum([latencies[i]*pj_computes[i] for i in range(4)]) / latency
print(latency)
print(pj_compute)
# Out:
# 43792
# 34.27583850931676

# %%
# 1 x 34
latencies = [18496, 18496, 2176, 4624]
pj_computes = [29.32, 29.35, 54.15, 50.66]
latency = sum(latencies)
pj_compute = sum([latencies[i]*pj_computes[i] for i in range(4)]) / latency
print(latency)
print(pj_compute)
# Out:
# 43792
# 32.819751552795026

# %%
# 34 x 34
latencies = [18496, 18496, 2176, 4624]
pj_computes = [32.23, 28.87, 52.97, 49.57]
latency = sum(latencies)
pj_compute = sum([latencies[i]*pj_computes[i] for i in range(4)]) / latency
print(latency)
print(pj_compute)
# Out:
# 43792
# 33.672360248447205

# %%
# 4 x 4
latencies = [18496, 18496, 2176, 4624]
pj_computes = [30.52, 33.60, 54.15, 50.05]
latency = sum(latencies)
pj_compute = sum([latencies[i]*pj_computes[i] for i in range(4)]) / latency
print(latency)
print(pj_compute)
# Out:
# 43792
# 35.0572049689441

# %%
# 1 x 16
latencies = [18496, 18496, 2176, 4624]
pj_computes = [29.35, 29.35, 54.15, 50.66]
latency = sum(latencies)
pj_compute = sum([latencies[i]*pj_computes[i] for i in range(4)]) / latency
print(latency)
print(pj_compute)
# Out:
# 43792
# 32.832422360248444

# %%
# 17 x 2
latencies = [18496, 18496, 2176, 4624]
pj_computes = [29.55, 29.42, 54.40, 50.52]
latency = sum(latencies)
pj_compute = sum([latencies[i]*pj_computes[i] for i in range(4)]) / latency
print(latency)
print(pj_compute)
# Out:
# 43792
# 32.94409937888199

# %%
# 34 x 1
latencies = [18496, 18496, 2176, 4624]
pj_computes = [32.58, 33.75, 53.32, 50.24]
latency = sum(latencies)
pj_compute = sum([latencies[i]*pj_computes[i] for i in range(4)]) / latency
print(latency)
print(pj_compute)
# Out:
# 43792
# 35.96944099378882
