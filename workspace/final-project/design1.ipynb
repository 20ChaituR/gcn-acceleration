# %%
import pandas as pd
import numpy as np
from loaders import *
import pandas as pd
import seaborn as sns

# %%
des1 = [run_timeloop_mapper(
    ConfigRegistry.DES1_ARCH,
    ConfigRegistry.DES1_COMPONENTS,
    prob,
    ConfigRegistry.DES1_CONSTRAINTS,
    ConfigRegistry.DES1_MAPPER
) for prob in [
    ConfigRegistry.PROB_LAYER1,
    ConfigRegistry.PROB_LAYER2,
    ConfigRegistry.PROB_LAYER3,
    ConfigRegistry.PROB_LAYER4]]
# Out:
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension I = 16
#   Factorization options along problem dimension O = 35
#   Factorization options along problem dimension N = 9
# Mapspace Dimension [IndexFactorization] Size: 5040
# Mapspace Dimension [LoopPermutation] Size: 1296
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 630 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  7] Utilization = 0.12 | pJ/Compute =  209.418 | L5[IWO] N34 O8 I17 - L4[IWO] I2 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.06 | pJ/Compute =   88.579 | L5[IWO] N17 O4 - L4[IWO] N2 O2 - L3[] O2 I34 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 0.12 | pJ/Compute =  209.418 | L5[IWO] N34 O8 I34 - L4[IWO] N1 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.06 | pJ/Compute =   51.887 | L5[IWO] O4 N17 - L4[IWO] N2 O2 - L3[] O2 I34 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.12 | pJ/Compute =  209.418 | L5[IWO] N34 O8 I2 - L4[IWO] I17 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.06 | pJ/Compute =   35.686 | L5[IWO] O2 N17 - L4[IWO] N2 - L3[] O8 I34 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =  209.418 | L5[IWO] N34 O8 I2 - L4[IWO] N1 O2Y - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.06 | pJ/Compute =   35.054 | L5[IWO] O2 N17 - L4[IWO] N2 - L3[O] I34 O8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.12 | pJ/Compute =  206.697 | L5[IWO] O8 I17 N34 - L4[IWO] I2 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.12 | pJ/Compute =  160.405 | L5[IWO] N34 I2 O8 - L4[IWO] I17 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.12 | pJ/Compute =  209.418 | L5[IWO] N34 O8 I17 - L4[IWO] N1 O2Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.12 | pJ/Compute =   53.065 | L5[IWO] O4 I17 - L4[IWO] N34 O2 I2 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =  160.405 | L5[IWO] N34 I2 O8 - L4[IWO] N1 O2Y - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] STATEMENT: 15000 invalid mappings (15000 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  2] Utilization = 0.12 | pJ/Compute =  160.071 | L5[IWO] N34 I2 O8 - L4[IWO] N1 O2Y - L3[I] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.12 | pJ/Compute =   35.014 | L5[IWO] O2 N17 - L4[IWO] O2 O2Y - L3[] N2 O2 I34 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   91.311 | L5[IWO] O8 I2 N34 - L4[IWO] N1 O2Y - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   90.238 | L5[IWO] O8 I2 N34 - L4[IWO] N1 O2Y - L3[W] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.50 | pJ/Compute =   33.465 | L5[IWO] N2 I17 - L4[IWO] N17 I2 O8Y - L3[] O2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.12 | pJ/Compute =   91.311 | L5[IWO] O8 I2 N34 - L4[IWO] I17 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.50 | pJ/Compute =   32.544 | L5[IWO] N2 I17 - L4[IWO] N17 I2 O8Y - L3[O] O2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.12 | pJ/Compute =  206.697 | L5[IWO] O8 I17 N34 - L4[IWO] N1 O2Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 0.12 | pJ/Compute =   54.207 | L5[IWO] O4 I34 - L4[IWO] N34 O2 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   43.378 | L5[IWO] O2 I2 N34 - L4[IWO] O8 - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   42.456 | L5[IWO] O2 I2 N34 - L4[IWO] O8 - L3[I] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.12 | pJ/Compute =  205.625 | L5[IWO] O8 I17 N34 - L4[IWO] N1 O2Y - L3[W] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0
 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =   36.557 | L5[IWO] I2 N17 - L4[IWO] I17 O16Y - L3[] N2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =   34.234 | L5[IWO] I2 N17 - L4[IWO] I17 O16Y - L3[O] N2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =   34.018 | L5[IWO] I2 N34 - L4[IWO] I17 O16Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =   31.770 | L5[IWO] N2 I34 - L4[IWO] N17 O16Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] Utilization = 1.00 | pJ/Compute =   31.987 | L5[IWO] N2 I17 - L4[IWO] N17 I2 O16Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   29.352 | L5[IWO] N2 I34 - L4[IWO] N1 O16Y - L3[O] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] Utilization = 1.00 | pJ/Compute =   31.770 | L5[IWO] N2 I17 - L4[IWO] I2 O16Y - L3[] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   29.352 | L5[IWO] N2 I17 - L4[IWO] I2 O16Y - L3[O] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   29.352
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension I = 16
#   Factorization options along problem dimension O = 35
#   Factorization options along problem dimension N = 9
# Mapspace Dimension [IndexFactorization] Size: 5040
# Mapspace Dimension [LoopPermutation] Size: 1296
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 630 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  2] Utilization = 0.12 | pJ/Compute =  335.217 | L5[IWO] N34 O8 I2 - L4[IWO] N1 O2Y - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =  282.393 | L5[IWO] N34 I2 O8 - L4[IWO] N1 O2Y - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.06 | pJ/Compute =  150.378 | L5[IWO] N17 O4 - L4[IWO] N2 O2 - L3[] O2 I34 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =  282.058 | L5[IWO] N34 I2 O8 - L4[IWO] N1 O2Y - L3[I] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   89.063 | L5[IWO] O8 I2 N34 - L4[IWO] N1 O2Y - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.06 | pJ/Compute =   53.452 | L5[IWO] O4 N17 - L4[IWO] N2 O2 - L3[] O2 I34 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 0.12 | pJ/Compute =  335.217 | L5[IWO] N34 O8 I34 - L4[IWO] N1 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.12 | pJ/Compute =  335.217 | L5[IWO] N34 O8 I2 - L4[IWO] I17 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.12 | pJ/Compute =  282.393 | L5[IWO] N34 I2 O8 - L4[IWO] I17 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.12 | pJ/Compute =  335.217 | L5[IWO] N34 O8 I17 - L4[IWO] I2 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.12 | pJ/Compute =  335.217 | L5[IWO] N34 O8 I17 - L4[IWO] N1 O2Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   86.645 | L5[IWO] O8 I2 N34 - L4[IWO] N1 O2Y - L3[O] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] STATEMENT: 15000 invalid mappings (15000 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  0] Utilization = 0.06 | pJ/Compute =   37.250 | L5[IWO] O2 N17 - L4[IWO] N2 - L3[] O8 I34 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] STATEMENT: 15000 invalid mappings (15000 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  1] Utilization = 0.12 | pJ/Compute =  209.418 | L5[IWO] O8 I34 N34 - L4[IWO] N1 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.06 | pJ/Compute =   36.400 | L5[IWO] O2 N17 - L4[IWO] N2 - L3[W] I34 O8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.12 | pJ/Compute =   89.063 | L5[IWO] O8 I2 N34 - L4[IWO] I17 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.12 | pJ/Compute =  147.267 | L5[IWO] O8 I17 N34 - L4[IWO] N1 O2Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.12 | pJ/Compute =  144.850 | L5[IWO] O8 I17 N34 - L4[IWO] N1 O2Y - L3[O] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.12 | pJ/Compute =   53.871 | L5[IWO] O4 I17 - L4[IWO] N34 O2 O2Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   41.130 | L5[IWO] O2 I2 N34 - L4[IWO] O8 - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.12 | pJ/Compute =  147.267 | L5[IWO] O8 I17 N34 - L4[IWO] I2 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 0.12 | pJ/Compute =   54.207 | L5[IWO] O4 I34 - L4[IWO] N34 O2 O2Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0
y - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.50 | pJ/Compute =   37.537 | L5[IWO] O2 I2 N34 - L4[IWO] N1 O8Y - L3[O] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.50 | pJ/Compute =   36.074 | L5[IWO] O2 N17 - L4[IWO] N2 I34 O8Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =   31.987 | L5[IWO] I2 N17 - L4[IWO] I17 O16Y - L3[] N2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =   30.961 | L5[IWO] I2 N17 - L4[IWO] I17 O16Y - L3[W] N2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   31.770 | L5[IWO] I2 N17 - L4[IWO] N1 O16Y - L3[] N2 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   29.352 | L5[IWO] I2 N17 - L4[IWO] N1 O16Y - L3[O] N2 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] Utilization = 0.50 | pJ/Compute =   36.074 | L5[IWO] O2 N17 - L4[IWO] N2 I17 O8Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 0.50 | pJ/Compute =   34.510 | L5[IWO] O2 I34 - L4[IWO] N2 O8Y - L3[] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =   34.018 | L5[IWO] N2 I34 - L4[IWO] N17 O16Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.50 | pJ/Compute =   35.732 | L5[IWO] O2 N17 - L4[IWO] I17 O8Y - L3[WO] N2 I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.50 | pJ/Compute =   35.287 | L5[IWO] O2 N17 - L4[IWO] I17 O8Y - L3[W] I2 N2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.50 | pJ/Compute =   34.625 | L5[IWO] O2 I17 - L4[IWO] N2 I2 O8Y - L3[] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.50 | pJ/Compute =   34.292 | L5[IWO] O2 I17 - L4[IWO] N2 I2 O8Y - L3[W] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   36.557 | L5[IWO] N2 I17 - L4[IWO] N17 I2 O16Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =   32.945 | L5[IWO] N2 I34 - L4[IWO] N1 O16Y - L3[W] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   34.018 | L5[IWO] N2 I17 - L4[IWO] I2 O16Y - L3[] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   32.945 | L5[IWO] N2 I17 - L4[IWO] I2 O16Y - L3[W] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   29.352
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension I = 35
#   Factorization options along problem dimension O = 10
#   Factorization options along problem dimension N = 9
# Mapspace Dimension [IndexFactorization] Size: 3150
# Mapspace Dimension [LoopPermutation] Size: 1296
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 394 Residue: 2
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  2] Utilization = 0.06 | pJ/Compute =  215.169 | L5[IWO] N34 O2 I4 - L4[IWO] N1 - L3[] O2 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.25 | pJ/Compute =   55.467 | L5[IWO] I2 - L4[IWO] N34 I8 O4Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  214.835 | L5[IWO] N34 O2 I4 - L4[IWO] N1 - L3[I] O2 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  214.727 | L5[IWO] N34 O2 I4 - L4[IWO] N1 - L3[O] O2 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  214.394 | L5[IWO] N34 O2 I4 - L4[IWO] N1 - L3[IO] O2 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.25 | pJ/Compute =   55.221 | L5[IWO] N34 - L4[IWO] I16 O4Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 0.25 | pJ/Compute =   55.958 | L5[IWO] I4 - L4[IWO] N34 O4Y - L3[] I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 0.25 | pJ/Compute =   54.886 | L5[IWO] I4 - L4[IWO] N34 O4Y - L3[W] I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.12 | pJ/Compute =   59.369 | L5[IWO] N2 O2 - L4[IWO] N17 O2Y - L3[] I16 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.12 | pJ/Compute =   58.343 | L5[IWO] N2 O2 - L4[IWO] N17 O2Y - L3[W] I16 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.25 | pJ/Compute =   55.221 | L5[IWO] N2 - L4[IWO] N17 I16 O4Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.25 | pJ/Compute =   55.221 | L5[IWO] N34 - L4[IWO] I4 O4Y - L3[] I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 0.25 | pJ/Compute =   55.467 | L5[IWO] I2 - L4[IWO] N34 I4 O4Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.25 | pJ/Compute =   56.941 | L5[IWO] I8 - L4[IWO] N34 I2 O4Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 0.25 | pJ/Compute =   56.941 | L5[IWO] I8 - L4[IWO] N34 O4Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 0.25 | pJ/Compute =   55.869 | L5[IWO] I8 - L4[IWO] N34 O4Y - L3[W] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  137.671 | L5[IWO] O2 I4 N34 - L4[IWO] N1 - L3[] O2 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  137.338 | L5[IWO] O2 I4 N34 - L4[IWO] N1 - L3[I] O2 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  136.599 | L5[IWO] O2 I4 N34 - L4[IWO] N1 - L3[W] O2 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  136.266 | L5[IWO] O2 I4 N34 - L4[IWO] N1 - L3[IW] O2 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.25 | pJ/Compute =   55.221 | L5[IWO] N34 - L4[IWO] I8 O4Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   56.475 | L5[IWO] N17 - L4[IWO] N2 O2 I2 - L3[] O2 I8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   56.141 | L5[IWO] N17 - L4[IWO] N2 O2 I2 - L3[I] O2 I8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   56.013 | L5[IWO] N17 - L4[IWO] N2 O2 I2 - L3[IO] O2 I8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.25 | pJ/Compute =   54.149 | L5[IWO] N2 - L4[IWO] N17 O4Y - L3[W] I16 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 0.25 | pJ/Compute =   55.221 | L5[IWO] N34 - L4[IWO] I2 O4Y - L3[] I8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   93.275 | L5[IWO] N2 O2 I8 - L4[IWO] I2 O2Y - L3[] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   90.955 | L5[IWO] N2 O2 I8 - L4[IWO] I2 O2Y - L3[O] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   59.369 | L5[IWO] N2 O2 - L4[IWO] N17 I2 O2Y - L3[] I8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   57.277 | L5[IWO] I8 - L4[IWO] N17 O2Y - L3[] N2 O2 I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   56.205 | L5[IWO] I8 - L4[IWO] N17 O2Y - L3[W] N2 O2 I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.12 | pJ/Compute =   55.853 | L5[IWO] N17 - L4[IWO] N2 I4 O2Y - L3[O] O2 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.25 | pJ/Compute =   71.568 | L5[IWO] I2 N34 - L4[IWO] I8 O4Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.25 | pJ/Compute =   56.655 | L5[IWO] I16 - L4[IWO] N1 O4Y - L3[] N34 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 0.25 | pJ/Compute =   55.467 | L5[IWO] I2 - L4[IWO] N1 O4Y - L3[] N34 I8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 0.25 | pJ/Compute =   54.395 | L5[IWO] I2 - L4[IWO] N1 O4Y - L3[W] N34 I8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 0.25 | pJ/Compute =   54.603 | L5[IWO] I2 - L4[IWO] N2 I8 O4Y - L3[O] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 0.25 | pJ/Compute =   54.149 | L5[IWO] N34 - L4[IWO] N1 O4Y - L3[W] I16 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.25 | pJ/Compute =   54.395 | L5[IWO] I2 - L4[IWO] N17 O4Y - L3[W] N2 I8 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 0.25 | pJ/Compute =   55.000 | L5[IWO] I4 - L4[IWO] N2 I4 O4Y - L3[O] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.25 | pJ/Compute =   54.886 | L5[IWO] I4 - L4[IWO] N1 O4Y - L3[W] N34 I4 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 0.25 | pJ/Compute =   54.149
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension I = 16
#   Factorization options along problem dimension O = 10
#   Factorization options along problem dimension N = 9
# Mapspace Dimension [IndexFactorization] Size: 1440
# Mapspace Dimension [LoopPermutation] Size: 1296
# Mapspace Dimension [Spatial] Size: 1
# Mapspace Dimension [DatatypeBypass] Size: 8
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 180 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  1] Utilization = 0.25 | pJ/Compute =   50.879 | L5[IWO] I34 - L4[IWO] N34 O4Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.25 | pJ/Compute =   53.535 | L5[IWO] I17 - L4[IWO] N34 O4Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 0.25 | pJ/Compute =   52.444 | L5[IWO] N34 - L4[IWO] I34 O4Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.25 | pJ/Compute =   51.117 | L5[IWO] I17 - L4[IWO] N34 O4Y - L3[O] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  335.957 | L5[IWO] N34 O2 I2 - L4[IWO] N1 - L3[] O2 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  335.624 | L5[IWO] N34 O2 I2 - L4[IWO] N1 - L3[I] O2 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  307.367 | L5[IWO] N34 I2 O2 - L4[IWO] N1 - L3[] O2 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =  306.641 | L5[IWO] N34 I2 O2 - L4[IWO] N1 - L3[I] O2 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.25 | pJ/Compute =   52.444 | L5[IWO] N34 - L4[IWO] N1 O4Y - L3[] I34 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.25 | pJ/Compute =   53.535 | L5[IWO] I17 - L4[IWO] N34 I2 O4Y - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.25 | pJ/Compute =   52.444 | L5[IWO] N34 - L4[IWO] I17 O4Y - L3[] I2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   89.735 | L5[IWO] O2 I2 N34 - L4[IWO] N1 - L3[] O2 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   89.401 | L5[IWO] O2 I2 N34 - L4[IWO] N1 - L3[I] O2 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] STATEMENT: 15000 invalid mappings (15000 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  6] STATEMENT: 15000 invalid mappings (15000 fanout, 0 capacity) found since the last valid mapping, terminating search.
# [  2] Utilization = 0.06 | pJ/Compute =   57.332 | L5[IWO] I2 N17 - L4[IWO] O2 - L3[] N2 O2 I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   57.329 | L5[IWO] I2 N17 - L4[IWO] O2 - L3[W] N2 I17 O2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.06 | pJ/Compute =   56.523 | L5[IWO] I2 N17 - L4[IWO] O2 - L3[W] O2 I17 N2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.25 | pJ/Compute =   60.089 | L5[IWO] N2 I2 - L4[IWO] N17 O4Y - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.25 | pJ/Compute =   57.765 | L5[IWO] N2 I2 - L4[IWO] N17 O4Y - L3[O] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.25 | pJ/Compute =   56.324 | L5[IWO] I2 N2 - L4[IWO] N17 O4Y - L3[] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.25 | pJ/Compute =   53.906 | L5[IWO] I2 N2 - L4[IWO] N17 O4Y - L3[O] I17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 0.25 | pJ/Compute =   51.657 | L5[IWO] N17 - L4[IWO] N1 O4Y - L3[W] I34 N2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.25 | pJ/Compute =   52.395 | L5[IWO] I17 - L4[IWO] N17 I2 O4Y - L3[W] N2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.25 | pJ/Compute =   50.995 | L5[IWO] I17 - L4[IWO] N2 I2 O4Y - L3[] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 0.25 | pJ/Compute =   50.661 | L5[IWO] I17 - L4[IWO] N2 I2 O4Y - L3[W] N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 0.25 | pJ/Compute =   53.781 | L5[IWO] I2 N2 - L4[IWO] N1 O4Y - L3[W] I17 N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] Utilization = 0.25 | pJ/Compute =   50.995 | L5[IWO] I17 - L4[IWO] N2 O4Y - L3[] I2 N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 0.25 | pJ/Compute =   50.661 | L5[IWO] I17 - L4[IWO] N2 O4Y - L3[W] I2 N17 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 0.25 | pJ/Compute =   50.661

# %%
print(des1[1][1])
# Out:
# DRAM [ Inputs:1156 (1156) Weights:544 (544) Outputs:544 (544) ]
# ---------------------------------------------------------------
# | for I in [0:2)
# |   for N in [0:17)
#
# global_buffer [ Inputs:34 (34) Weights:32 (32) Outputs:272 (272) ]
# ------------------------------------------------------------------
# |     for N in [0:1)
# |       for O in [0:16) (Spatial-Y)
#
# scratchpad [ Outputs:17 (17) ]
# ------------------------------
# |         for N in [0:2)
# |           for I in [0:17)
#
# weights_reg [ Weights:1 (1) ]
# -----------------------------
# |             for N in [0:1)
#
# input_activation_reg [ Inputs:1 (1) ]
# -------------------------------------
# |               for N in [0:1)
#
# output_activation_reg [ Outputs:1 (1) ]
# ---------------------------------------
# |                 for N in [0:1)

# %%
print(des1[0][0])
# Out:
# Buffer and Arithmetic Levels
# ----------------------------
# Level 0
# -------
# === mac ===
#
#     SPECS
#     -----
#     Word bits             : 16
#     Instances             : 16 (1*16)
#     Compute energy        : 3.27 pJ
#
#     STATS
#     -----
#     Utilized instances      : 16
#     Computes (total)        : 18496
#     Cycles                  : 1156
#     Energy (total)          : 60574.40 pJ
#     Area (total)            : 27624.00 um^2
#
# Level 1
# -------
# === output_activation_reg ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 16 (1*16)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 1
#         Min utilization             : 0.00
#         Vector access energy        : 0.01 pJ
#         Vector access energy source : ERT
#         Area                        : 5.98 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 1156
#     Bandwidth throttling : 1.00
#     Outputs:
#         Partition size                           : 34
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 16
#         Utilized clusters (max)                  : 16
#         Scalar reads (per-instance)              : 1122
#         Scalar updates (per-instance)            : 1156
#         Scalar fills (per-instance)              : 1156
#         Temporal reductions (per-instance)       : 1122
#         Address generations (per-cluster)        : 2312
#         Energy (per-scalar-access)               : 0.97 pJ
#         Energy (per-instance)                    : 3348.06 pJ
#         Energy (total)                           : 53568.89 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 2.97 words/cycle
#         Shared Bandwidth (total)                 : 47.53 words/cycle
#         Read Bandwidth (per-instance)            : 0.97 words/cycle
#         Read Bandwidth (total)                   : 15.53 words/cycle
#         Write Bandwidth (per-instance)           : 2.00 words/cycle
#         Write Bandwidth (total)                  : 32.00 words/cycle
#
# Level 2
# -------
# === input_activation_reg ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 16 (1*16)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 1
#         Min utilization             : 0.00
#         Vector access energy        : 0.01 pJ
#         Vector access energy source : ERT
#         Area                        : 5.98 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 1156
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 1156
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 16
#         Utilized clusters (max)                  : 16
#         Scalar reads (per-instance)              : 1156
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 1156
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 2312
#         Energy (per-scalar-access)               : 0.97 pJ
#         Energy (per-instance)                    : 2254.14 pJ
#         Energy (total)                           : 36066.18 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 2.00 words/cycle
#         Shared Bandwidth (total)                 : 32.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 16.00 words/cycle
#         Write Bandwidth (per-instance)           : 1.00 words/cycle
#         Write Bandwidth (total)                  : 16.00 words/cycle
#
# Level 3
# -------
# === weights_reg ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 1
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 16 (1*16)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 1
#         Min utilization             : 0.00
#         Vector access energy        : 0.01 pJ
#         Vector access energy source : ERT
#         Area                        : 5.98 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#
#     STATS
#     -----
#     Cycles               : 1156
#     Bandwidth throttling : 1.00
#     Weights:
#         Partition size                           : 34
#         Utilized capacity                        : 1
#         Utilized instances (max)                 : 16
#         Utilized clusters (max)                  : 16
#         Scalar reads (per-instance)              : 1156
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 68
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1224
#         Energy (per-scalar-access)               : 0.97 pJ
#         Energy (per-instance)                    : 1193.37 pJ
#         Energy (total)                           : 19093.86 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.06 words/cycle
#         Shared Bandwidth (total)                 : 16.94 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 16.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.06 words/cycle
#         Write Bandwidth (total)                  : 0.94 words/cycle
#
# Level 4
# -------
# === scratchpad ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 18
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 16 (1*16)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 18
#         Min utilization             : 0.00
#         Vector access energy        : 0.23 pJ
#         Vector access energy source : ERT
#         Area                        : 292.55 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for N in [0:17)
#
#     STATS
#     -----
#     Cycles               : 1156
#     Bandwidth throttling : 1.00
#     Outputs:
#         Partition size                           : 34
#         Utilized capacity                        : 17
#         Utilized instances (max)                 : 16
#         Utilized clusters (max)                  : 16
#         Scalar reads (per-instance)              : 1122
#         Scalar updates (per-instance)            : 1156
#         Scalar fills (per-instance)              : 34
#         Temporal reductions (per-instance)       : 1122
#         Address generations (per-cluster)        : 1190
#         Energy (per-scalar-access)               : 0.23 pJ
#         Energy (per-instance)                    : 521.59 pJ
#         Energy (total)                           : 8345.40 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 2.00 words/cycle
#         Shared Bandwidth (total)                 : 32.00 words/cycle
#         Read Bandwidth (per-instance)            : 0.97 words/cycle
#         Read Bandwidth (total)                   : 15.53 words/cycle
#         Write Bandwidth (per-instance)           : 1.03 words/cycle
#         Write Bandwidth (total)                  : 16.47 words/cycle
#
# Level 5
# -------
# === global_buffer ===
#
#     SPECS
#     -----
#         Technology                  : SRAM
#         Size                        : 512
#         Word bits                   : 16
#         Block size                  : 1
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : 512
#         Min utilization             : 0.00
#         Vector access energy        : 1.61 pJ
#         Vector access energy source : ERT
#         Area                        : 7021.76 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for O in [0:16) (Spatial-Y)
#
#     STATS
#     -----
#     Cycles               : 1156
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 1156
#         Utilized capacity                        : 17
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 1156
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 1156
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 2312
#         Energy (per-scalar-access)               : 1.48 pJ
#         Energy (per-instance)                    : 3416.69 pJ
#         Energy (total)                           : 3416.69 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 2.00 words/cycle
#         Shared Bandwidth (total)                 : 2.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 1.00 words/cycle
#         Write Bandwidth (per-instance)           : 1.00 words/cycle
#         Write Bandwidth (total)                  : 1.00 words/cycle
#     Weights:
#         Partition size                           : 544
#         Utilized capacity                        : 16
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 1088
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 1088
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 2176
#         Energy (per-scalar-access)               : 1.48 pJ
#         Energy (per-instance)                    : 3215.70 pJ
#         Energy (total)                           : 3215.70 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.88 words/cycle
#         Shared Bandwidth (total)                 : 1.88 words/cycle
#         Read Bandwidth (per-instance)            : 0.94 words/cycle
#         Read Bandwidth (total)                   : 0.94 words/cycle
#         Write Bandwidth (per-instance)           : 0.94 words/cycle
#         Write Bandwidth (total)                  : 0.94 words/cycle
#     Outputs:
#         Partition size                           : 544
#         Utilized capacity                        : 272
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar updates (per-instance)            : 544
#         Scalar fills (per-instance)              : 544
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1088
#         Energy (per-scalar-access)               : 1.61 pJ
#         Energy (per-instance)                    : 1753.45 pJ
#         Energy (total)                           : 1753.45 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 0.94 words/cycle
#         Shared Bandwidth (total)                 : 0.94 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.94 words/cycle
#         Write Bandwidth (total)                  : 0.94 words/cycle
#
# Level 6
# -------
# === DRAM ===
#
#     SPECS
#     -----
#         Technology                  : DRAM
#         Size                        : -
#         Word bits                   : 16
#         Block size                  : 4
#         Cluster size                : 1
#         Instances                   : 1 (1*1)
#         Shared bandwidth            : -
#         Read bandwidth              : -
#         Write bandwidth             : -
#         Multiple buffering          : 1.00
#         Effective size              : -
#         Min utilization             : 0.00
#         Vector access energy        : 512.00 pJ
#         Vector access energy source : ERT
#         Area                        : 0.00 um^2
#
#     MAPPING
#     -------
#     Loop nest:
#       for N in [0:2)
#         for I in [0:34)
#
#     STATS
#     -----
#     Cycles               : 1156
#     Bandwidth throttling : 1.00
#     Inputs:
#         Partition size                           : 1156
#         Utilized capacity                        : 1156
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 1156
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1156
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 147968.00 pJ
#         Energy (total)                           : 147968.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 1.00 words/cycle
#         Shared Bandwidth (total)                 : 1.00 words/cycle
#         Read Bandwidth (per-instance)            : 1.00 words/cycle
#         Read Bandwidth (total)                   : 1.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Weights:
#         Partition size                           : 544
#         Utilized capacity                        : 544
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 1088
#         Scalar updates (per-instance)            : 0
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 1088
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 139264.00 pJ
#         Energy (total)                           : 139264.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 0.94 words/cycle
#         Shared Bandwidth (total)                 : 0.94 words/cycle
#         Read Bandwidth (per-instance)            : 0.94 words/cycle
#         Read Bandwidth (total)                   : 0.94 words/cycle
#         Write Bandwidth (per-instance)           : 0.00 words/cycle
#         Write Bandwidth (total)                  : 0.00 words/cycle
#     Outputs:
#         Partition size                           : 544
#         Utilized capacity                        : 544
#         Utilized instances (max)                 : 1
#         Utilized clusters (max)                  : 1
#         Scalar reads (per-instance)              : 0
#         Scalar updates (per-instance)            : 544
#         Scalar fills (per-instance)              : 0
#         Temporal reductions (per-instance)       : 0
#         Address generations (per-cluster)        : 544
#         Energy (per-scalar-access)               : 128.00 pJ
#         Energy (per-instance)                    : 69632.00 pJ
#         Energy (total)                           : 69632.00 pJ
#         Temporal Reduction Energy (per-instance) : 0.00 pJ
#         Temporal Reduction Energy (total)        : 0.00 pJ
#         Address Generation Energy (per-cluster)  : 0.00 pJ
#         Address Generation Energy (total)        : 0.00 pJ
#         Shared Bandwidth (per-instance)          : 0.47 words/cycle
#         Shared Bandwidth (total)                 : 0.47 words/cycle
#         Read Bandwidth (per-instance)            : 0.00 words/cycle
#         Read Bandwidth (total)                   : 0.00 words/cycle
#         Write Bandwidth (per-instance)           : 0.47 words/cycle
#         Write Bandwidth (total)                  : 0.47 words/cycle
#
# Networks
# --------
# Network 0
# ---------
# DRAM <==> global_buffer
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1088.00
#             @multicast 1 @scatter 1: 1088.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 544.00
#             @multicast 1 @scatter 1: 544.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 1
# ---------
# global_buffer <==> scratchpad
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Inputs:
#         Fanout                                  : 16
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 16
#         Ingresses                               : 1156.00
#             @multicast 16 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 15.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Weights:
#         Fanout                                  : 16
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1088.00
#             @multicast 1 @scatter 16: 1088.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 2.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 16
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 544.00
#             @multicast 1 @scatter 16: 544.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 2.00
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 2
# ---------
# input_activation_reg <==> output_activation_reg
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 3
# ---------
# output_activation_reg <==> mac
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 4
# ---------
# scratchpad <==> weights_reg
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 68.00
#             @multicast 1 @scatter 1: 68.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
# Network 5
# ---------
# weights_reg <==> input_activation_reg
#
#     SPECS
#     -----
#         Type            : Legacy
#         Legacy sub-type :
#         ConnectionType  : 3
#         Word bits       : 16
#         Router energy   : - pJ
#         Wire energy     : - pJ/b/mm
#         Fill latency     : 0
#         Drain latency     : 0
#
#     STATS
#     -----
#     Inputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Weights:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#     Outputs:
#         Fanout                                  : 1
#         Fanout (distributed)                    : 0
#         Multicast factor                        : 1
#         Ingresses                               : 1156.00
#             @multicast 1 @scatter 1: 1156.00
#         Link transfers                          : 0
#         Spatial reductions                      : 0
#         Average number of hops                  : 0.50
#         Energy (per-hop)                        : 0.00 fJ
#         Energy (per-instance)                   : 0.00 pJ
#         Energy (total)                          : 0.00 pJ
#         Link transfer energy (per-instance)     : 0.00 pJ
#         Link transfer energy (total)            : 0.00 pJ
#         Spatial Reduction Energy (per-instance) : 0.00 pJ
#         Spatial Reduction Energy (total)        : 0.00 pJ
#
#
# Operational Intensity Stats
# ---------------------------
#     Total elementwise ops                   : 18496
#     Total reduction ops                     : 17952
#     Total ops                               : 36448
#     Total memory accesses required          : 2244
#     Optimal Op per Byte                     : 8.12
#
# === output_activation_reg ===
#     Total scalar accesses                   : 54944
#     Op per Byte                             : 0.33
# === input_activation_reg ===
#     Total scalar accesses                   : 36992
#     Op per Byte                             : 0.49
# === weights_reg ===
#     Total scalar accesses                   : 19584
#     Op per Byte                             : 0.93
# === scratchpad ===
#     Total scalar accesses                   : 36992
#     Op per Byte                             : 0.49
# === global_buffer ===
#     Total scalar accesses                   : 5576
#     Op per Byte                             : 3.27
# === DRAM ===
#     Total scalar accesses                   : 2788
#     Op per Byte                             : 6.54
#
#
# Summary Stats
# -------------
# GFLOPs (@1GHz): 31.53
# Utilization: 1.00
# Cycles: 1156
# Energy: 0.54 uJ
# EDP(J*cycle): 6.28e-04
# Area: 0.00 mm^2
#
# Computes = 18496
# pJ/Compute
#     mac                                             = 3.27
#     output_activation_reg                           = 2.90
#     input_activation_reg                            = 1.95
#     weights_reg                                     = 1.03
#     scratchpad                                      = 0.45
#     global_buffer                                   = 0.45
#     DRAM                                            = 19.29
#     DRAM <==> global_buffer                         = 0.00
#     global_buffer <==> scratchpad                   = 0.00
#     input_activation_reg <==> output_activation_reg = 0.00
#     output_activation_reg <==> mac                  = 0.00
#     scratchpad <==> weights_reg                     = 0.00
#     weights_reg <==> input_activation_reg           = 0.00
#     Total                                           = 29.35
